# %% [markdown]
# Install Lib

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install investpy
# Out:
# Collecting investpy
#   Using cached investpy-1.0.8-py3-none-any.whl
# Collecting lxml>=4.4.1
#   Using cached lxml-4.8.0-cp37-cp37m-win_amd64.whl (3.6 MB)
# Collecting numpy>=1.21.2
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# Requirement already satisfied: pytz>=2019.3 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from investpy) (2022.1)
# Collecting requests>=2.22.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting setuptools>=41.2.0
#   Using cached setuptools-62.1.0-py3-none-any.whl (1.1 MB)
# Collecting pandas>=0.25.1
#   Using cached pandas-1.1.5-cp37-cp37m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: Unidecode>=1.1.1 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from investpy) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from pandas>=0.25.1->investpy) (2.7.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (1.23)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2018.8.24)
# Requirement already satisfied: six>=1.5 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.11.0)
# Installing collected packages: setuptools, numpy, lxml, charset-normalizer, requests, pandas, investpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.15.1
#     Uninstalling numpy-1.15.1:
#       Successfully uninstalled numpy-1.15.1
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.5
#     Uninstalling lxml-4.2.5:
#       Successfully uninstalled lxml-4.2.5
#   Attempting uninstall: requests
#     Found existing installation: requests 2.19.1
#     Uninstalling requests-2.19.1:
#       Successfully uninstalled requests-2.19.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.23.4
#     Uninstalling pandas-0.23.4:
#       Successfully uninstalled pandas-0.23.4
# Successfully installed charset-normalizer-2.0.12 investpy-1.0.8 lxml-4.8.0 numpy-1.21.6 pandas-1.1.5 requests-2.27.1 setuptools-62.1.0
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)

# %%
import sys
# !{sys.executable} -m pip install  plotly
# Out:
# Collecting plotly
#   Using cached plotly-5.7.0-py2.py3-none-any.whl (28.8 MB)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from plotly) (1.11.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.7.0 tenacity-8.0.1
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)

# %%
import sys
# !{sys.executable} -m pip install  ta
# Out:
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from ta) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->ta) (2.7.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.11.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py): started
#   Building wheel for ta (setup.py): finished with status 'done'
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28995 sha256=beca13ebb0f6b613cf134a4bc3b17e9e1ee9e51bbd86eb8083b76b8e0d0eb8d1
#   Stored in directory: c:\users\hari.moura\appdata\local\pip\cache\wheels\bc\2a\c2\a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -etuptools (c:\users\hari.moura\appdata\local\continuum\anaconda3\lib\site-packages)

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import investpy as ip
# import streamlit as st
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from datetime import datetime, timedelta
import plotly.express as px

import seaborn as sns
from scipy.signal import argrelextrema
from ta import add_all_ta_features

# %% [markdown]
# ## Define intervals and countries

# %%
countries = ['brazil', 'united states']#n countries
intervals = ['Daily','Weekly','Monthly']

# %% [markdown]
# ## Function to get historical data from investpy

# %%
def search_stocks(stock, country, from_date, to_date, interval):
    print("stock =>",stock)
    return ip.get_stock_historical_data(stock=stock,
                                  country=country,
                                  from_date=from_date,
                                  to_date=to_date,
                                  interval=interval)

# %% [markdown]
# ## Get AAPL records and test

# %%
aapl = search_stocks("AAPL", countries[1], '13/04/2020', '22/04/2022', intervals[0])
# Out:
# stock => AAPL

# %% [markdown]
# ### Test .head .desxcribe and .tail

# %% [markdown]
# Head

# %%
aapl.head()
# Out:
#              Open   High    Low  Close     Volume Currency  Diff
# Date
# 2020-04-13  67.08  68.43  66.46  68.31  131023000      USD -1.23
# 2020-04-14  70.00  72.06  69.51  71.76  194995008      USD -1.76
# 2020-04-15  70.60  71.58  70.16  71.11  131155000      USD -0.51
# 2020-04-16  71.85  72.05  70.59  71.67  157124992      USD  0.18
# 2020-04-17  71.17  71.74  69.21  70.70  215250000      USD  0.47

# %% [markdown]
# Tail

# %%
aapl.tail()

# %% [markdown]
# Describe

# %%
aapl.describe()

# %%
print(aapl.columns)
print(aapl.index)

# %%
#Last 10
aapl["Close"][-10:]

# %%
## loc usage
# print(aapl.loc[ pd.Timestamp("2020-11-01") : pd.Timestamp("2020-12-31") ].head())
## First rows fromgiven date
# print(aapl.loc["2020"].head())
## iloc usage
# print(aapl.iloc[22:43])# from index x(22) to index y(43)

# %%
aapl.sample(20)

# %%
aapl.resample('M').mean()

# %%
aapl.asfreq('M', method="bfill")

# %%
aapl['Diff'] = aapl.Open - aapl.Close
aapl['Diff']
# Out:
# Date
# 2020-04-13   -1.23
# 2020-04-14   -1.76
# 2020-04-15   -0.51
# 2020-04-16    0.18
# 2020-04-17    0.47
#               ...
# 2022-04-18   -1.15
# 2022-04-19   -2.38
# 2022-04-20    1.53
# 2022-04-21    2.49
# 2022-04-22    3.25
# Name: Diff, Length: 513, dtype: float64

# %%
# aapl["Diff"].plot(grid=True)
# aapl["Close"].plot(grid=True)

# %%
# fig = px.line(aapl, y="Close")
fig = make_subplots(
        rows=2, 
        cols=1, 
        shared_xaxes=True, 
        specs=[[{"secondary_y": False}], [{"secondary_y": True}]],
        vertical_spacing=0.03,
        subplot_titles=('AAPL OHLC', intervals[0]),
        row_width=[0.2, 0.7],
#     print_grid=True
)

# fig.add_trace(
#     go.Candlestick(
#     x=aapl.index, 
#     open=aapl['Open'], 
#     high=aapl['High'], 
#     low=aapl['Low'], 
#     close=aapl['Close']), 
#     row=1, 
#     col=1
# )


fig.add_trace( 
    go.Scatter( 
        x=aapl.index, 
        y=aapl["Close"],
        mode="lines",
        name="Close"
    )
)

fig.add_trace( 
    go.Scatter( x=aapl.index, 
        y=aapl["Diff"],
        mode="lines",
        name="Diff"
    )
)

aapl["i"] = np.arange(len(aapl))

min_local_rg = 30

local_max_idx = argrelextrema(aapl["Diff"].values, np.greater, order = min_local_rg)

# print(local_max_idx)
local_max_idx = np.array(local_max_idx)[0]

# print(local_max_idx)
local_max =[]

for loc in local_max_idx:
    local_max.append(aapl.Diff[loc])

aapl["diff_local_max"] = 0
# print(local_max_idx)
aapl.loc[ aapl["i"].isin(local_max_idx), "diff_local_max" ] = 1
# print(aapl["diff_local_max"])
# print(aapl)

from ta.utils import dropna



aapl["sma20"] = aapl["Close"].rolling(window=20).mean()
aapl["sma30"] = aapl["Close"].rolling(window=30).mean()

aapl["ema20"]= aapl["Close"].ewm(span=20, adjust=False).mean()
aapl["ema30"]= aapl["Close"].ewm(span=50, adjust=False).mean()

fig.add_trace(
    go.Scatter(x=aapl["sma30"].index, 
        y=aapl["sma30"],
        mode="lines",
               line_color="orange",
        name="sma30",
        opacity=0.72
)
,row=1, col=1)

fig.add_trace(
    go.Scatter(x=aapl["sma20"].index, 
        y=aapl["sma20"],
        mode="lines",
        name="sma20",
               line_color="yellow",
        opacity=0.72
)
,row=1, col=1)

# fig.add_trace(
#     go.Scatter(x=aapl["ema30"].index, 
#         y=aapl["ema30"],
#         mode="lines",
#                line_color="green",
#         name="ema30",
#         opacity=0.72
# )
# ,row=1, col=1)

# fig.add_trace(
#     go.Scatter(x=aapl["ema20"].index, 
#         y=aapl["ema20"],
#         mode="lines",
#                line_color="cyan",
#         name="ema20",
#         opacity=0.72
# )
# ,row=1, col=1)

aapl["sma20"] = aapl[aapl["sma20"] <= aapl["sma30"]]["sma20"].astype("int64") 
aapl["sma30"] =  aapl[aapl["sma20"] <= aapl["sma30"]]["sma30"].astype("int64") 

fig.add_trace(
    go.Scatter(x=aapl[aapl["sma20"] == aapl["sma30"]].index, 
        y=aapl[aapl["sma20"] == aapl["sma30"]]["Close"],
        mode="markers",
        name="Cross",
        marker_color="springgreen",
        marker_symbol="x",
        marker_size=7,
        opacity=0.62
)
,row=1, col=1)


fig.add_trace(
    go.Scatter(x=aapl[aapl["diff_local_max"] == 1].index, 
        y=aapl[aapl["diff_local_max"] == 1]["Diff"],
        mode="markers",
        name="max",
        marker_color="cyan",
        marker_symbol="x",
        marker_size=7,
        opacity=0.62
)
,row=1, col=1)


fig.update_layout(
    template="plotly_dark", 
    xaxis_rangeslider_visible=False,
    height=700
)

fig.show()
# Out:
# <div>                            <div id="c7e0dc11-95d9-4414-aacf-a4d9bd518a53" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7e0dc11-95d9-4414-aacf-a4d9bd518a53")) {                    Plotly.newPlot(                        "c7e0dc11-95d9-4414-aacf-a4d9bd518a53",                        [{"mode":"lines","name":"Close","x":["2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","2020-11-06T00:00:00","2020-11-09T00:00:00","2020-11-10T00:00:00","2020-11-11T00:00:00","2020-11-12T00:00:00","2020-11-13T00:00:00","2020-11-16T00:00:00","2020-11-17T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00"," ...

# %%
# ip.moving_averages(name='AAPL', country=countries[1], product_type='stock', interval='daily')
# from ta.trend import EMAIndicator
# ema5 = EMAIndicator(aapl["Close"],5)
# aapl["EMA5"] = ema5.ema_indicator()
# aapl["EMA5"].plot(grid=True)
# aapl["Close"].plot(grid=True)
# aapl["Close"].rolling(window=20).mean().plot()
# aapl["Close"].rolling(window=50).mean().plot()

# intEqual = lambda a,b: a - b
aapl.loc["2020-09-23"]
# intEqual(aapl["sma20"] , aapl["sma30"].value)
# aapl["sma30"].value
# add_all_ta_features(aapl, open="Open", high="High", low="Low", close="Close", volume="Volume")
# Out:
# Open                 111.62
# High                 112.11
# Low                  106.77
# Close                107.12
# Volume            150719008
# Currency                USD
# Diff                    4.5
# i                       114
# diff_local_max            0
# sma20               117.882
# sma30               117.993
# ema20               114.093
# ema30               110.282
# Name: 2020-09-23 00:00:00, dtype: object

# %%
aapl["Close"].rolling(window=20).mean().plot()

# %% [markdown]
# Get PETR Preferred and Ordinary stock

# %%
# def getAllStocks
petr3 = search_stocks("PETR3", countries[0], '13/04/2020', '13/04/2022', intervals[0])
petr4 = search_stocks("PETR4", countries[0], '13/04/2020', '13/04/2022', intervals[0])
# Out:
# stock => PETR3
# stock => PETR4

# %%
round((petr3/petr4),3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a75dd27c42d6> in <module>()
# ----> 1 round((petr3/petr4),3)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     653         if isinstance(other, ABCDataFrame):
#     654             # Another DataFrame
# --> 655             new_data = self._combine_frame(other, na_op, fill_value)
#     656
#     657         elif isinstance(other, ABCSeries):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _combine_frame(self, other, func, fill_value)
#    5868                 return func(left, right)
#    5869
# -> 5870         new_data = ops.dispatch_to_series(self, other, _arith_op)
#    5871         return new_data
#    5872
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, axis)
#     273         #  _frame_arith_method_with_reindex
#     274
# --> 275         bm = left._mgr.operate_blockwise(right._mgr, array_op)
#     276         return type(left)(bm)
#     277
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#     365         Apply array_op blockwise with another (aligned) BlockManager.
#     366         """
# --> 367         return operate_blockwise(self, other, array_op)
#     368
#     369     def apply(self: T, f, align_keys=None, **kwargs) -> T:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      36             lvals, rvals = _get_same_shape_values(blk, rblk, left_ea, right_ea)
#      37
# ---> 38             res_values = array_op(lvals, rvals)
#      39             if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      40                 res_values = res_values.reshape(1, -1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
